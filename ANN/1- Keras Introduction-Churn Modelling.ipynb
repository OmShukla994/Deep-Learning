# %% [markdown]
# ## Churn Modellling
# - wheather customer will exist in future or not

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow.keras as keras

# %%
# Importing the dataset
dataset = pd.read_csv(r'C:\Users\DELL\Downloads\2024\Churn_Modelling.csv')
X = dataset.iloc[:, 3:13]
y = dataset.iloc[:, 13]

# %%
#Create dummy variables
geography=pd.get_dummies(X["Geography"],drop_first=True)
gender=pd.get_dummies(X['Gender'],drop_first=True)

# %%
## Concatenate the Data Frames

X=pd.concat([X,geography,gender],axis=1)

# %%
## Drop Unnecessary columns
X=X.drop(['Geography','Gender'],axis=1)

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# Feature Scaling is required in DL becoz forward and back propogation happen quickly
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Importing the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout #regularization parameter, mostly used in neural network

# %%
# Initialising the ANN
classifier = Sequential()

# Adding the input layer and the first hidden layer. so we have 11 I/P with 6 hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'he_uniform',activation='relu',input_dim = 11))

# Adding the second hidden layer. again we use 6 hidden layer again
classifier.add(Dense(units = 6, kernel_initializer = 'he_uniform',activation='relu'))
# Adding the output layer. Output has 1 with sigmoid layer
classifier.add(Dense(units = 1, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))
# Out:
# C:\Users\DELL\anaconda3\envs\DL_AI\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compiling the ANN. loss is binary becoz its a binary problem
classifier.compile(optimizer = 'Adamax', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# Fitting the ANN to the Training set
model_history=classifier.fit(X_train, y_train,validation_split=0.33, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7865 - loss: 0.5747 - val_accuracy: 0.7955 - val_loss: 0.5291
# Epoch 2/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8102 - loss: 0.5068 - val_accuracy: 0.7955 - val_loss: 0.5107
# Epoch 3/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7890 - loss: 0.5085 - val_accuracy: 0.7955 - val_loss: 0.4989
# Epoch 4/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7972 - loss: 0.4943 - val_accuracy: 0.7955 - val_loss: 0.4898
# Epoch 5/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7976 - loss: 0.4801 - val_accuracy: 0.7955 - val_loss: 0.4824
# Epoch 6/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7852 - loss: 0.4868 - val_accuracy: 0.7955 - val_loss: 0.4763
# Epoch 7/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7860 - loss: 0.4828 - val_accuracy: 0.7955 - val_loss: 0.4710
# Epoch 8/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7908 - loss: 0.4701 - val_accuracy: 0.7955 - val_loss: 0.4656
# Epoch 9/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7926 - loss: 0.4621 - val_accuracy: 0.7955 - val_loss: 0.4610
# Epoch 10/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7944 - loss: 0.4549 - val_accuracy: 0.7955 - val_loss: 0.4567
# Epoch 11/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7945 - loss: 0.4466 - val_accuracy: 0.7955 - val_loss: 0.4524
# Epoch 12/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7905 - loss: 0.4514 - val_accuracy: 0.7955 - val_loss: 0.4486
# Epoch 13/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7951 - loss: 0.4442 - val_accuracy: 0.7955 - val_loss: 0.4450
# Epoch 14/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7876 - loss: 0.4457 - val_accuracy: 0.7948 - val_loss: 0.4417
# Epoch 15/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8017 - loss: 0.4368 - val_accuracy: 0.7978 - val_loss: 0.4386
# Epoch 16/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8005 - loss: 0.4381 - val_accuracy: 0.8008 - val_loss: 0.4359
# Epoch 17/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7975 - loss: 0.4347 - val_accuracy: 0.8008 - val_loss: 0.4338
# Epoch 18/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8036 - loss: 0.4354 - val_accuracy: 0.8001 - val_loss: 0.4314
# Epoch 19/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8112 - loss: 0.4251 - val_accuracy: 0.8020 - val_loss: 0.4289
# Epoch 20/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8069 - loss: 0.4190 - val_accuracy: 0.8042 - val_loss: 0.4270
# Epoch 21/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8145 - loss: 0.4157 - val_accuracy: 0.8061 - val_loss: 0.4250
# Epoch 22/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8137 - loss: 0.4120 - val_accuracy: 0.8061 - val_loss: 0.4232
# Epoch 23/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8088 - loss: 0.4216 - val_accuracy: 0.8084 - val_loss: 0.4215
# Epoch 24/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8118 - loss: 0.4189 - val_accuracy: 0.8107 - val_loss: 0.4200
# Epoch 25/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8154 - loss: 0.4102 - val_accuracy: 0.8114 - val_loss: 0.4183
# Epoch 26/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8154 - loss: 0.4110 - val_accuracy: 0.8107 - val_loss: 0.4169
# Epoch 27/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8121 - loss: 0.4114 - val_accuracy: 0.8111 - val_loss: 0.4153
# Epoch 28/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8079 - loss: 0.4225 - val_accuracy: 0.8122 - val_loss: 0.4143
# Epoch 29/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8302 - loss: 0.3901 - val_accuracy: 0.8145 - val_loss: 0.4127
# Epoch 30/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8175 - loss: 0.4095 - val_accuracy: 0.8164 - val_loss: 0.4114
# Epoch 31/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8261 - loss: 0.3949 - val_accuracy: 0.8171 - val_loss: 0.4101
# Epoch 32/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8103 - loss: 0.4045 - val_accuracy: 0.8186 - val_loss: 0.4091
# Epoch 33/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8191 - loss: 0.4036 - val_accuracy: 0.8175 - val_loss: 0.4078
# Epoch 34/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8246 - loss: 0.3844 - val_accuracy: 0.8198 - val_loss: 0.4068
# Epoch 35/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8155 - loss: 0.3969 - val_accuracy: 0.8205 - val_loss: 0.4057
# Epoch 36/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8103 - loss: 0.4021 - val_accuracy: 0.8209 - val_loss: 0.4047
# Epoch 37/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8303 - loss: 0.3889 - val_accuracy: 0.8198 - val_loss: 0.4035
# Epoch 38/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8215 - loss: 0.3915 - val_accuracy: 0.8209 - val_loss: 0.4026
# Epoch 39/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8325 - loss: 0.3784 - val_accuracy: 0.8198 - val_loss: 0.4017
# Epoch 40/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8226 - loss: 0.4001 - val_accuracy: 0.8209 - val_loss: 0.4007
# Epoch 41/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8290 - loss: 0.3817 - val_accuracy: 0.8217 - val_loss: 0.4000
# Epoch 42/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8232 - loss: 0.3892 - val_accuracy: 0.8217 - val_loss: 0.3993
# Epoch 43/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8271 - loss: 0.3864 - val_accuracy: 0.8213 - val_loss: 0.3988
# Epoch 44/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8248 - loss: 0.3873 - val_accuracy: 0.8224 - val_loss: 0.3978
# Epoch 45/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8258 - loss: 0.3807 - val_accuracy: 0.8220 - val_loss: 0.3971
# Epoch 46/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8186 - loss: 0.3973 - val_accuracy: 0.8213 - val_loss: 0.3966
# Epoch 47/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8323 - loss: 0.3747 - val_accuracy: 0.8209 - val_loss: 0.3958
# Epoch 48/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8214 - loss: 0.3986 - val_accuracy: 0.8209 - val_loss: 0.3953
# Epoch 49/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8357 - loss: 0.3662 - val_accuracy: 0.8228 - val_loss: 0.3945
# Epoch 50/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8323 - loss: 0.3693 - val_accuracy: 0.8232 - val_loss: 0.3938
# Epoch 51/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8318 - loss: 0.3814 - val_accuracy: 0.8228 - val_loss: 0.3935
# Epoch 52/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8353 - loss: 0.3744 - val_accuracy: 0.8338 - val_loss: 0.3927
# Epoch 53/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8343 - loss: 0.3862 - val_accuracy: 0.8349 - val_loss: 0.3916
# Epoch 54/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8344 - loss: 0.3841 - val_accuracy: 0.8353 - val_loss: 0.3908
# Epoch 55/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8455 - loss: 0.3660 - val_accuracy: 0.8353 - val_loss: 0.3900
# Epoch 56/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8466 - loss: 0.3695 - val_accuracy: 0.8364 - val_loss: 0.3894
# Epoch 57/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8360 - loss: 0.3863 - val_accuracy: 0.8345 - val_loss: 0.3888
# Epoch 58/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8385 - loss: 0.3761 - val_accuracy: 0.8364 - val_loss: 0.3877
# Epoch 59/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8480 - loss: 0.3644 - val_accuracy: 0.8364 - val_loss: 0.3868
# Epoch 60/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8448 - loss: 0.3619 - val_accuracy: 0.8353 - val_loss: 0.3862
# Epoch 61/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8544 - loss: 0.3639 - val_accuracy: 0.8364 - val_loss: 0.3851
# Epoch 62/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8426 - loss: 0.3728 - val_accuracy: 0.8364 - val_loss: 0.3845
# Epoch 63/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8488 - loss: 0.3658 - val_accuracy: 0.8379 - val_loss: 0.3838
# Epoch 64/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8500 - loss: 0.3618 - val_accuracy: 0.8372 - val_loss: 0.3837
# Epoch 65/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8511 - loss: 0.3677 - val_accuracy: 0.8364 - val_loss: 0.3830
# Epoch 66/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8400 - loss: 0.3792 - val_accuracy: 0.8372 - val_loss: 0.3825
# Epoch 67/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8446 - loss: 0.3647 - val_accuracy: 0.8379 - val_loss: 0.3818
# Epoch 68/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8548 - loss: 0.3571 - val_accuracy: 0.8372 - val_loss: 0.3809
# Epoch 69/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8529 - loss: 0.3605 - val_accuracy: 0.8383 - val_loss: 0.3805
# Epoch 70/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8428 - loss: 0.3805 - val_accuracy: 0.8402 - val_loss: 0.3800
# Epoch 71/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8509 - loss: 0.3660 - val_accuracy: 0.8410 - val_loss: 0.3795
# Epoch 72/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8496 - loss: 0.3680 - val_accuracy: 0.8417 - val_loss: 0.3789
# Epoch 73/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8532 - loss: 0.3577 - val_accuracy: 0.8432 - val_loss: 0.3785
# Epoch 74/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8488 - loss: 0.3644 - val_accuracy: 0.8421 - val_loss: 0.3782
# Epoch 75/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8485 - loss: 0.3648 - val_accuracy: 0.8425 - val_loss: 0.3775
# Epoch 76/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8584 - loss: 0.3572 - val_accuracy: 0.8425 - val_loss: 0.3767
# Epoch 77/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8570 - loss: 0.3553 - val_accuracy: 0.8440 - val_loss: 0.3761
# Epoch 78/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8475 - loss: 0.3619 - val_accuracy: 0.8432 - val_loss: 0.3754
# Epoch 79/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8630 - loss: 0.3426 - val_accuracy: 0.8451 - val_loss: 0.3747
# Epoch 80/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8458 - loss: 0.3747 - val_accuracy: 0.8459 - val_loss: 0.3740
# Epoch 81/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8633 - loss: 0.3454 - val_accuracy: 0.8466 - val_loss: 0.3733
# Epoch 82/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8639 - loss: 0.3425 - val_accuracy: 0.8470 - val_loss: 0.3728
# Epoch 83/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8631 - loss: 0.3406 - val_accuracy: 0.8463 - val_loss: 0.3727
# Epoch 84/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8534 - loss: 0.3618 - val_accuracy: 0.8478 - val_loss: 0.3720
# Epoch 85/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8531 - loss: 0.3601 - val_accuracy: 0.8463 - val_loss: 0.3714
# Epoch 86/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8565 - loss: 0.3481 - val_accuracy: 0.8463 - val_loss: 0.3711
# Epoch 87/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8531 - loss: 0.3611 - val_accuracy: 0.8455 - val_loss: 0.3708
# Epoch 88/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8518 - loss: 0.3617 - val_accuracy: 0.8463 - val_loss: 0.3706
# Epoch 89/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8583 - loss: 0.3475 - val_accuracy: 0.8455 - val_loss: 0.3700
# Epoch 90/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8618 - loss: 0.3440 - val_accuracy: 0.8459 - val_loss: 0.3693
# Epoch 91/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8552 - loss: 0.3469 - val_accuracy: 0.8459 - val_loss: 0.3691
# Epoch 92/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8555 - loss: 0.3487 - val_accuracy: 0.8466 - val_loss: 0.3687
# Epoch 93/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8580 - loss: 0.3487 - val_accuracy: 0.8466 - val_loss: 0.3684
# Epoch 94/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8552 - loss: 0.3555 - val_accuracy: 0.8466 - val_loss: 0.3680
# Epoch 95/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8683 - loss: 0.3380 - val_accuracy: 0.8470 - val_loss: 0.3676
# Epoch 96/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8553 - loss: 0.3495 - val_accuracy: 0.8466 - val_loss: 0.3673
# Epoch 97/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8553 - loss: 0.3518 - val_accuracy: 0.8466 - val_loss: 0.3672
# Epoch 98/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8550 - loss: 0.3473 - val_accuracy: 0.8466 - val_loss: 0.3669
# Epoch 99/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8520 - loss: 0.3472 - val_accuracy: 0.8474 - val_loss: 0.3665
# Epoch 100/100
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8551 - loss: 0.3502 - val_accuracy: 0.8489 - val_loss: 0.3663

# %%
# list all data in history

print(model_history.history.keys())
# summarize history for accuracy
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Part 3 - Making the predictions and evaluating the model

# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# Calculate the Accuracy
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)
